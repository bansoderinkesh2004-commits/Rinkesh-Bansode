# %% [markdown]
# <a href="https://colab.research.google.com/github/bansoderinkesh2004-commits/Rinkesh-Bansode/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("musafir cafe")
menu={"pizza":199, "sandwich":99, "cold coffee":35, "hot coffee":29, "burger":149,}
print(menu)
item=input("enter item")
print("you've ordered:", item)
total=0
while item !="done":
  total+=menu[item]
  item=input("enter item")
  print(total)
# Out:
# musafir cafe
# {'pizza': 199, 'sandwich': 99, 'cold coffee': 35, 'hot coffee': 29, 'burger': 149}
# enter itempizza
# you've ordered: pizza
# enter itemdone
# 199
