# %% [markdown]
# <a href="https://colab.research.google.com/github/bansoderinkesh2004-commits/Rinkesh-Bansode/blob/main/12/09/2026.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
num1 = float(input("Enter first number: "))
num2 = float(input("Enter second number: "))
op = input("Enter operator (+, -, *, /): ")

if op == "+":
    print("Result:", num1 + num2)
elif op == "-":
    print("Result:", num1 - num2)
elif op == "*":
    print("Result:", num1 * num2)
elif op == "/":
    print("Result:", num1 / num2)
else:
    print("Invalid operator")
# Out:
# Enter first number: 5
# Enter second number: 6
# Enter operator (+, -, *, /): +
# Result: 11.0
